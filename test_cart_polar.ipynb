# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib.path import Path

from utils.polar_cartesian import Cart2Polar, Polar2Cart
p256_to_c256 = Polar2Cart(polar_size=(256, 256), cart_size=(256, 256))
c256_to_p64 = Cart2Polar(polar_size=(64, 1024), cart_size=(256, 256))

# %%
dummy_cart_256 = torch.zeros((1, 4, 256, 256))
dummy_polar_64 = torch.zeros((1, 4, 64, 1024))

# %%
bev = plt.imread("/home/workspace/work/TripleMOS/images/c_label.png")
bev = torch.from_numpy(bev).permute(2,0,1).unsqueeze(0)

# plt imshow 크기 늘리기
plt.figure(figsize=(5, 5))
plt.imshow(bev[0].permute(1,2,0).numpy())
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
plt.figure(figsize=(20, 5))
rv = c256_to_p64(bev, dummy_polar_64)
plt.imshow(rv[0].permute(1,2,0).numpy())
plt.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 1023.5, 63.5, -0.5)

# %%
bev = p256_to_c256(rv, dummy_cart_256)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(bev[0].permute(1,2,0).numpy())
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
# !echo $DISPLAYw
# Out:
# 117.16.153.158:0
